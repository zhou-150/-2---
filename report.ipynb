# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
da=pd.read_csv('unemployment-rate.csv')
da
# Out:
#    year  Kaohsiung  New Taipei  Taipei  Taoyuan  Taichung  Tainan
# 0  2013        4.2         4.2     4.2      4.3       4.1     4.2
# 1  2014        3.9         3.9     4.0      4.0       3.9     4.1
# 2  2015        3.8         3.7     3.8      3.9       3.8     3.8
# 3  2016        4.0         3.9     3.9      4.0       3.8     3.9
# 4  2017        3.8         3.8     3.8      3.9       3.7     3.8
# 5  2018        3.7         3.7     3.7      3.8       3.7     3.8
# 6  2019        3.7         3.8     3.7      3.8       3.7     3.7
# 7  2020        3.8         3.9     3.9      4.0       3.9     3.8

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x="year", y="Kaohsiung",data=da,label="Kaohsiung",color='blue')
sns.lineplot(x="year", y="New Taipei",data=da,label="New Taipei",color='red')
sns.lineplot(x="year", y="Taipei",data=da,label="Taipei",color='green')
sns.lineplot(x="year", y="Taoyuan",data=da,label="Taoyuan",color='purple')
sns.lineplot(x="year", y="Taichung",data=da,label="Taichung",color='black')
sns.lineplot(x="year", y="Tainan",data=da,label="Tainan",color='yellow',linewidth="3")

plt.ylabel("unemployment rate")
# Out:
# Text(0, 0.5, 'unemployment rate')

# %%
sns.set_theme(style="darkgrid")
sns.distplot(da['Taoyuan'])
# Out:
# <AxesSubplot:xlabel='Taoyuan', ylabel='Density'>

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x="year", y="Taoyuan",data=da,label="Taoyuan",color='purple')
plt.ylabel("unemployment rate")
# Out:
# Text(0, 0.5, 'unemployment rate')

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x="year", y="Tainan",data=da,label="Tainan",color='yellow',linewidth="3")
plt.ylabel("unemployment rate")
# Out:
# Text(0, 0.5, 'unemployment rate')

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x="year", y="Taichung",data=da,label="Taichung",color='black')
plt.ylabel("unemployment rate")
# Out:
# Text(0, 0.5, 'unemployment rate')
